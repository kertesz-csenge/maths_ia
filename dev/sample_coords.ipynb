# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
A=(5.0400654920648,0.0344629349447)
C=(0.4427678081307,1.5212035080068)
D=(0.7999122862435,2.5078224437503)
E=(3.336389981814,3.4600120555616)
F=(5.6459569596094,2.7741348494085)
G=(6.4757271569233,1.4813300897804)
H=(5.9439134472436,0.6394071420449)
I=(5.557994860134,0.2562255661913)
J=(2.3006077040432,0.0445978242934)
K=(5.2393714280031,0.1722687535077)
L=(2.2444914233319,0.1747875955436)
X=(0.9347771784421,0.6794745259997)

##c = [J, L, X, C, D, E, F, G, H, I, K, A]
c = [J, L, X, C, D, E, F, G, H, I, A]

x = []
y = []
for xv, yv in c:
    x.append(xv)
    y.append(yv)

plt.axis("equal")
plt.plot(x, y, "ro-", linewidth=2, markersize=4)

# %%
print(x)
print(y)
# Out:
# [2.3006077040432, 2.2444914233319, 0.9347771784421, 0.4427678081307, 0.7999122862435, 3.336389981814, 5.6459569596094, 6.4757271569233, 5.9439134472436, 5.557994860134, 5.0400654920648]
# [0.0445978242934, 0.1747875955436, 0.6794745259997, 1.5212035080068, 2.5078224437503, 3.4600120555616, 2.7741348494085, 1.4813300897804, 0.6394071420449, 0.2562255661913, 0.0344629349447]
